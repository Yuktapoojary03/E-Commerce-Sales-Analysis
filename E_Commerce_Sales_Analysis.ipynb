# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuktapoojary03/E-Commerce-Sales-Analysis/blob/main/E_Commerce_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_excel("/content/Ecommerce_Sales_Analysis_Data.xlsx")

# %%
# Basic information
print(df.head())
print(df.info())
# Out:
#    Order_ID  Order_Date Customer_ID       Product     Category  Quantity  \
# 0      1001  2025-03-13        C299         Shoes      Fashion         4
# 1      1002  2025-01-12        C670        Laptop  Electronics         1
# 2      1003  2025-11-16        C502    Desk Chair         Home         4
# 3      1004  2025-12-13        C525    Desk Chair         Home         3
# 4      1005  2025-04-26        C555  Coffee Maker         Home         2
#
#    Unit_Price  Sales       City
# 0        3000  12000    Chennai
# 1       55000  55000      Delhi
# 2        7000  28000      Delhi
# 3        7000  21000  Bangalore
# 4        4500   9000      Delhi
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order_ID     200 non-null    int64
#  1   Order_Date   200 non-null    object
#  2   Customer_ID  200 non-null    object
# ...

# %%
# Total Sales
total_sales = df["Sales"].sum()
print("Total Sales:", total_sales)
# Out:
# Total Sales: 6654600

# %%
# Sales by Category
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
print(category_sales)
# Out:
# Category
# Electronics    4945000
# Home           1365000
# Fashion         344600
# Name: Sales, dtype: int64

# %%
# Top Selling Products
product_sales = df.groupby("Product")["Sales"].sum().sort_values(ascending=False)
print(product_sales)
# Out:
# Product
# Laptop          4675000
# Desk Chair       798000
# Coffee Maker     567000
# Headphones       270000
# Shoes            267000
# T-Shirt           77600
# Name: Sales, dtype: int64

# %%
# Monthly Sales Trend
df["Order_Date"] = pd.to_datetime(df["Order_Date"])
df["Month"] = df["Order_Date"].dt.month_name()
monthly_sales = df.groupby("Month")["Sales"].sum()
print(monthly_sales)
# Out:
# Month
# April        480600
# August        83100
# December     710100
# February     522300
# January      759500
# July         849800
# June         728900
# March        530400
# May          846000
# November     347300
# October      192300
# September    604300
# Name: Sales, dtype: int64

# %%
# Plot 1: Category Sales
category_sales.plot(kind="bar")
plt.title("Sales by Category")
plt.ylabel("Sales")
plt.tight_layout()
plt.show()

# %%
# Plot 2: Top Products
product_sales.plot(kind="bar")
plt.title("Top Selling Products")
plt.ylabel("Sales")
plt.tight_layout()
plt.show()

# %%
# Plot 3: Monthly Sales Trend
monthly_sales.plot(kind="line", marker="o")
plt.title("Monthly Sales Trend")
plt.ylabel("Sales")
plt.tight_layout()
plt.show()
